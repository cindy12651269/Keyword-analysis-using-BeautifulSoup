# %% [markdown]
# <a href="https://colab.research.google.com/github/cindy12651269/Keyword-analysis-using-BeautifulSoup/blob/cindy12651269%2Fhw1/Keyword_analysis_using_BeautifulSoup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

# 利用 requests 對 API 來源發送一個請求
response = requests.get('https://udn.com/news/breaknews/1')
soup = BeautifulSoup(response.text)

news = []

for link in soup.find_all('h3', class_='rounded-thumb__title')[:4]:
#找出所有<h3>標籤且class為'rounded-thumb__title的元素，取前4個
  news_url = link.a['href']
  #對該url發送請求
  news_response = requests.get('https://udn.com' + news_url)
  #解析該新聞畫面的HTML
  news_soup = BeautifulSoup(news_response.text,'html.parser')
  #使用html.parser將HTML內容解析成樹狀結構
  news_content = news_soup.find('div', class_='article-content__paragraph').text.strip().replace('\n', ' ')
  #找出class為'article-content__paragraph的div元素，strip去除空格、換行符，replace把換行符'\n'換成空格
  news.append(news_content)
print(news)
# Out:
# ['現正在印尼日惹舉行的2024年亞洲青少年羽球錦標賽傳出噩耗，中國大陸年僅17歲的男單小將張志傑，昨天傍晚出戰日本隊的比賽中突然抽搐、倒在場上，雖馬上被救護車送到醫院，搶救後仍在昨天當地時間11點20分去世，消息一出震驚羽壇。 \r 2007年出生的張志傑，2022年獲得中國U15男單冠軍，今年也摘下荷蘭青年國際賽男單冠軍，去年就進入國家青年隊，是中國備受期待的新生代好手。昨天團體賽，比賽進行到11：11時，張志傑突然倒地抽搐，場邊教練馬上入場觀察張志傑狀況，大會也馬上將張志傑送往醫院，最終搶救無效。            \r 亞青賽傳出噩耗，亞洲羽毛球聯合會、印尼羽球協會都表示非常悲痛，亞洲羽球協會聲明表示「世界羽壇失去了一位天才選手」。 \r 目前張志傑猝逝原因還沒公告，有一說法是心肌梗塞，也有許多中國網友猜測和新冠肺炎疫情有關。       羽球', '針對基隆市長謝國樑將被罷免，有地方政壇人士受訪時指出，罷免案通過的機會並不高，卻凸顯謝國樑仍以傳統方式施政造成的破口，包括東岸商場、電動機車等政策都處理不佳。該受訪人士提醒，基隆漸漸有很多從雙北移入的年輕人口，謝國樑若繼續以傳統國民黨思維辦事，恐難獲得基隆新選民認同，民進黨也會趁機反攻。 謝國樑因為基隆東岸商場爭議、電動機車等案件，讓公民團體「山海公民拆樑行動」決議發動罷免提案，且罷免案引發的骨牌效應不容小覷。團體29日表示，「罷免基隆市長謝國樑」行動第二階段連署，已至少收到3.6萬份連署書，超過門檻，預估將衝到4萬份，目前預定7月5日送件審查。            提醒謝國樑改變施政 對此，上述不具名基隆政壇人士受訪時指出，罷免案低空飛過連署門檻應該不成問題，但投票通過的機會不高，只是此事對謝國樑已經造成傷害，若以正面角度來看，罷免行動對於謝國樑是重要的警惕。 該人士指出，罷免行動一路捲動到可以成案，已經不能單純視為藍綠鬥爭，顯見謝國樑的城市治理與政治手段已經不足以回應市民的期待。該人士觀察指出，謝國樑在選舉期間、當選至今的1年多內，還是用比較傳統的政治思維，城市治理手段也是。該人士表示，罷免案雖不會致命，不同意罷免應該會大於同意，但也是謝國樑自我反省的契機。 市府危機處理不佳 「謝國樑似乎不擅長面對媒體！」這位政壇人士則強調，若從議題角度分析，今年初的東岸商場停車場爭議，謝國樑在危機處理上不但方式錯誤，還錯過處理案件的最佳時機，不然產權爭議若真正要追溯的話，前市長林右昌的政治與法律責任可能更大，此事讓罷免的火苗開始燃燒，且謝國樑有時還誤添柴火，導致更多麻煩出現。 該人士強調，由於謝國樑處理方式錯誤，導致大家對於東岸商場案只剩下他半夜帶警察破門闖入的負面形象，而忽略了真正與NET、大日政商關係始終交代不清楚的林右昌，這也導致林右昌八年執政留下來的爛攤子會被輕放。 政策多變選民不買單 上述政壇人士分析，謝國樑努力推動的電動機車政策，讓基隆市民不滿的不是政策買票，而是方案從1.0變到3.0，讓人看到謝國樑處理政見落實缺乏整體規劃的思考，表面看起來是滾動式修正，實際上是跳來跳去的改方案，基隆民眾自然感到不滿。 「基隆外來選民日益增加，已非過去傳統結構！」政壇人士表示，日前謝國樑陣營有民調流出顯示，基隆市內傳統深藍的信義區對謝國樑的滿意度最高，但同為傳統深藍選區，暖暖區的滿意度卻是最低，這是因為過去10到15年的人口結構變化很大，加上許多年輕人口（尤其49歲以下）從雙北移入基隆，他們對政治要求更高，若繼續用傳統思維治理，恐無法獲得這些選民認同。 至於這件事情是否會引發骨牌效應？政壇人士認為很有可能，民眾在檢視謝國樑施政的同時，也會同時放大檢視基隆立委林沛祥在國會的表現，而在民進黨往前推進全台大罷免的過程，基隆民進黨籍議長童子瑋就有機會從中得利，產生的漣漪效應仍在。【更多精采內容，詳見】      罷免 謝國樑', '00929投資週年回顧 你還在等上車嗎？ \r 雪倫從2023/7/27開始投資00929 到今天也將近一年的時間。 \r 從第一次下單2張買入金額16.25元到現在累積76張，平持持有成本大約17.74～17.94元 (券都被借光了，現在只能手動計算大約成本)以6/28收盤價20.88元來看，報酬大約17.7%（以平均成本17.74元計算）。            \r 如果要問我投資一年的心得；我只能用既開心又懊悔來形容。  開心的是有及早買進00929現在才能月月領股息，偶爾還能兼小差賺借券收入。 \r 懊惱的是買的不夠多，原本目標100張，但看著它一直漲就有點入不了手。唉，看樣子得要鞭策自己日日買才有機會達到我的目標了！ \r 投資00929以來看過它被捧上天也看過它因為外資倒貨，股價修正被罵。 \r 但投資有時候就跟交朋友一樣，時間久了就知道可不可以交往。  00929目前持有的成分股，我個人覺得還OK，而且近三個月都維持配息0.2元，雪友可能看到0.2元較無感，如果說買一張每個月有200元股息就會很有感了！以雪倫目前持有76張來說，每個月可以領1.52萬元股息。\r 嘿！看到1.52萬元不要羡幕，投資00929每月領5萬元以上的大有人在，雪倫只能算小咖...\r 光羡幕不行動是永遠無法達標的，與其坐著流口水不如想想怎麼靠投資打造現金流！ \r 雪倫投資00929的經驗，投資真的要趁早，如果下不了手，就用定期定額再搭配，不定期不定額就可以大大提升勝率啦！\r 不管再怎麼看好一個投資商品都千萬不能歐印還有信貸投資哦！    ※免責申明：本文僅為個人投資觀點與紀錄，並非建議。申購前自行評估風險，並詳閱公開說明書。※\r ◎本文內容已獲財經雪倫授權，原文出處於此；未經同意禁止取用轉載。     00929復華台灣科技優息ETF 月配息', '基隆市長謝國樑身陷罷免案，國民黨立院黨團也將提案修選罷法，民眾黨團立場則是認為應提高連署門檻。不過民進黨團總召柯建銘日前警告，若藍白強推修法，必將引起民意更大反彈，直接謝國樑送上斷頭台（罷免案）。蔣萬安今天受訪表示，「為罷免罷免的政治操作，不僅會造成社會動盪，其實對民主也是一種傷害」，他認為，尊重選舉結果，也是民主精神非常重要的一環。 \r 對於外界認為，謝國樑的罷免連署衝高是因國會改革修法的仇恨值加諸在謝身上，蔣萬安也被問及修法看法，蔣認為，接下來國民黨團、民進黨團、民眾黨團都會在立法院討論，他則認為應該要審慎溝通、討論、交換意見。            \r 蔣萬安今天上午出席「台北健康養成記」慢性病防治宣導系列活動受訪，對於謝國樑罷免案可能通過第二階段連署，對於藍白修選罷法的看法，蔣說，應該要審慎溝通。     修法 柯建銘 罷免 蔣萬安 謝國樑']
